# %% [markdown]
# # Imports Librería

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
# Para importar el Helper
# %cd "/content/drive/Shareddrives/Redes de Piluchina/TP 1 de Redes"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# /content/drive/Shareddrives/Redes de Piluchina/TP 1 de Redes
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# importing Jupyter notebook from Helper.ipynb
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Se arma un dataframe en el cual se hizo la evaluacion de la regresion, para cada combinacion de caracteristicas establecidas en el analisis en el archivo análisis EDA. Y mediante crossvalidation se obtienen el MSE.

# %%
df_final = evaluarPosibilidades([2,3,4])

# %%
df_final
# Out:
#      Num_dataset  polFeatures  \
# 0              1            0
# 1              1            2
# 2              1            3
# 3              1            4
# 4              2            0
# ..           ...          ...
# 195           49            4
# 196           50            0
# 197           50            2
# 198           50            3
# 199           50            4
#
#                                              Atributos  \
# 0    [ Secondary structure penalty,  Molecular mass...
# 1    [ Secondary structure penalty,  Molecular mass...
# 2    [ Secondary structure penalty,  Molecular mass...
# 3    [ Secondary structure penalty,  Molecular mass...
# 4    [ Average deviation from standard exposed area...
# ..                                                 ...
# 195  [Fractional area of exposed non polar residue,...
# 196  [ Non polar exposed area, Euclidian distance, ...
# 197  [ Non polar exposed area, Euclidian distance, ...
# ...

# %% [markdown]
# Se eligen los 5 mejores modelos:

# %%
mejores_5 = n_mejores(df_final, 5)

# %%
mejores_5
# Out:
#    Num_dataset  polFeatures  \
# 0           49            4
# 1           14            3
# 2           35            3
# 3           11            4
# 4           49            3
#
#                                            Atributos  \
# 0  [Fractional area of exposed non polar residue,...
# 1  [Total surface area,  Spacial Distribution con...
# 2  [ Spacial Distribution constraints,  Non polar...
# 3  [Fractional area of exposed non polar part of ...
# 4  [Fractional area of exposed non polar residue,...
#
#                                              X_train  \
# 0  [[1.0, 1.3769248155557998, -0.5660023358462889...
# 1  [[1.0, 1.2607404926992067, -0.4837146435483716...
# 2  [[1.0, -0.2769982451440333, 0.1293735615047095...
# 3  [[1.0, 1.1450839612677306, 0.9461341616561538,...
# 4  [[1.0, 0.3517224676354671, -0.9200295932802016...
#
#                                               X_test  \
# 0  [[1.0, -1.7851891426256528, -0.211975078412376...
# ...

# %% [markdown]
# Se hacen las predicciones con las 5 mejores:

# %%
df_con_cosas = RegLinPredicction(mejores_5)

# %%
df_con_cosas
# Out:
#    Num_dataset  polFeatures  \
# 0           49            4
# 1           14            3
# 2           35            3
# 3           11            4
# 4           49            3
#
#                                            Atributos   MSE_mean   MSE_TEST
# 0  [Fractional area of exposed non polar residue,... -22.857012  22.728101
# 1  [Total surface area,  Spacial Distribution con... -23.061776  22.525860
# 2  [ Spacial Distribution constraints,  Non polar... -23.527663  24.744693
# 3  [Fractional area of exposed non polar part of ... -23.528172  24.593374
# 4  [Fractional area of exposed non polar residue,... -23.594277  23.158691

# %% [markdown]
# -------

# %% [markdown]
# Finalmente el mejor resultado se obtiene usando un polFeatures de orden 3 con los atributos correspondientes al data set 14 ya que es el de menor MSE_TEST.
# Ademas se puede ver que influye los atributos escogidos al la hora de usar el modelo, ya que para el dataset 49 no resulta lo mismo hacer un polFeatures de orden 3 o 4, y por ejemplo tampoco resulta lo mismo usar un polFeatures de orden 3 si se toman los atributos del data set 14 o 35.
